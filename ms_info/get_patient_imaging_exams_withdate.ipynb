# %%
import numpy as np
#import pbr
import os
from nipype.utils.filemanip import load_json
from pbr.workflows.nifti_conversion.utils import description_renamer
#heuristic = load_json(os.path.join(os.path.split(pbr.__file__)[0], "heuristic.json"))["filetype_mapper"]
import pandas as pd
from subprocess import Popen, PIPE
import pandas as pd
import argparse
from os.path import join

# %%
def get_all_mse(msid):
    cmd = ["ms_get_patient_imaging_exams", "--patient_id", msid]
    proc = Popen(cmd, stdout=PIPE)
    lines = [l.decode("utf-8").split() for l in proc.stdout.readlines()[5:]]
    tmp = pd.DataFrame(lines, columns=["mse", "date"])
    tmp["mse"] = "mse"+tmp.mse
    tmp["msid"] = msid
    date = tmp["date"]
    return tmp

# %%
tmp = pd.DataFrame(lines, columns=["mse", "date"])
    tmp["msid"] = msid
    mse = tmp["mse"]
    date2 = tmp["date"]

# %%
#get_numerical_msid = lambda x: str(int(x[2:]))

def get_all_mse(msid):
    cmd = ["ms_get_patient_imaging_exams", "--patient_id", msid]
    proc = Popen(cmd, stdout=PIPE)
    lines = [l.decode("utf-8").split() for l in proc.stdout.readlines()[5:]]
    tmp = pd.DataFrame(lines, columns=["mse", "date"])  
    tmp["mse"] = "mse"+tmp.mse
    tmp["msid"] = msid
    return date

#def get_date

def get_modality(mse, nii_type="T1"):
    output = pd.DataFrame(index=None)
    num = mse.split("mse")[-1]
    cmd = ["ms_dcm_exam_info", "-t", num]
    proc = Popen(cmd, stdout=PIPE)
    lines = [description_renamer(" ".join(l.decode("utf-8").split()[1:-1])) for l in proc.stdout.readlines()[8:]]
    if nii_type:
        files = filter_files(lines, nii_type, heuristic)
        output["nii"] = files
    else:
        output["nii"] = lines
    output["mse"] = mse
    return output

def filter_files(descrip,nii_type, heuristic):
    output = []
    for i, desc in enumerate(descrip):
        if desc in list(heuristic.keys()):
            if heuristic[desc] == nii_type:
                 output.append(desc)
    return output

if __name__ == '__main__':
    df = pd.read_csv("/data/henry6/gina/msid.csv")
    #msid_set = set(df['msid'])
    msid_set = set(df['MS Group Subject ID'])
    msid_set_sorted = sorted(list(msid_set))
    print("There are {} msid patient will be tested". format(len(msid_set_sorted)))
    
    
    for msid in msid_set_sorted:
        msid = str(msid)
        msid_ms = "ms" + str(msid)
        print(msid)

        out_filename = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/test/' + msid_ms + '.txt'
        mse_df = get_all_mse(msid)
        print(mse_df.mse)
        with open(out_filename, 'w') as f:
            mse_list = mse_df.mse
            for mse in mse_list:
                seriesDesc = get_modality(mse, "T1")
                print(seriesDesc["nii"], mse)
                if seriesDesc["nii"].any():
                    f.write("{}\n".format(mse))
# Out:
# There are 1163 msid patient will be tested
# 3
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-04fb6c019b6f> in <module>()
#      48
#      49         out_filename = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/test/' + msid_ms + '.txt'
# ---> 50         mse_df = get_all_mse(msid)
#      51         print(mse_df.mse)
#      52         with open(out_filename, 'w') as f:
#
# <ipython-input-11-04fb6c019b6f> in get_all_mse(msid)
#       5     proc = Popen(cmd, stdout=PIPE)
#       6     lines = [l.decode("utf-8").split() for l in proc.stdout.readlines()[5:]]
# ----> 7     tmp = pd.DataFrame(lines, columns=["mse", "date"])
#       8     tmp["mse"] = "mse"+tmp.mse
#       9     tmp["msid"] = msid
#
# ~/ginas_anaconda3.6/new/envs/gk3/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     312                     if is_named_tuple(data[0]) and columns is None:
#     313                         columns = data[0]._fields
# --> 314                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     315                     columns = _ensure_index(columns)
#     316
#
# ~/ginas_anaconda3.6/new/envs/gk3/lib/python3.5/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    5713     if isinstance(data[0], (list, tuple)):
#    5714         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 5715                                dtype=dtype)
#    5716     elif isinstance(data[0], collections.Mapping):
#    5717         return _list_of_dict_to_arrays(data, columns,
#
# ~/ginas_anaconda3.6/new/envs/gk3/lib/python3.5/site-packages/pandas/core/frame.py in _list_to_arrays(data, columns, coerce_float, dtype)
#    5792         content = list(lib.to_object_array(data).T)
#    5793     return _convert_object_array(content, columns, dtype=dtype,
# -> 5794                                  coerce_float=coerce_float)
#    5795
#    5796
#
# ~/ginas_anaconda3.6/new/envs/gk3/lib/python3.5/site-packages/pandas/core/frame.py in _convert_object_array(content, columns, coerce_float, dtype)
#    5851             # caller's responsibility to check for this...
#    5852             raise AssertionError('%d columns passed, passed data had %s '
# -> 5853                                  'columns' % (len(columns), len(content)))
#    5854
#    5855     # provide soft conversion of object dtypes
#
# AssertionError: 2 columns passed, passed data had 3 columns

# %%
__author__ = 'sf713420'

import numpy as np
import pbr
import os
from nipype.utils.filemanip import load_json
from pbr.workflows.nifti_conversion.utils import description_renamer
heuristic = load_json(os.path.join(os.path.split(pbr.__file__)[0], "heuristic.json"))["filetype_mapper"]
import pandas as pd
from subprocess import Popen, PIPE
import pandas as pd
import argparse
from os.path import join

#get_numerical_msid = lambda x: str(int(x[2:]))

def get_all_mse(msid):
    cmd = ["ms_get_patient_imaging_exams", "--patient_id", msid]
    proc = Popen(cmd, stdout=PIPE)
    lines = [l.decode("utf-8").split() for l in proc.stdout.readlines()[5:]]
    tmp = pd.DataFrame(lines, columns=["mse", "date"])
    tmp["mse"] = "mse"+tmp.mse
    tmp["msid"] = msid
    return tmp

def get_modality(mse, nii_type="T1"):
    output = pd.DataFrame(index=None)
    num = mse.split("mse")[-1]
    cmd = ["ms_dcm_exam_info", "-t", num]
    proc = Popen(cmd, stdout=PIPE)
    lines = [description_renamer(" ".join(l.decode("utf-8").split()[1:-1])) for l in proc.stdout.readlines()[8:]]
    if nii_type:
        files = filter_files(lines, nii_type, heuristic)
        output["nii"] = files
    else:
        output["nii"] = lines
    output["mse"] = mse
    return output

def filter_files(descrip,nii_type, heuristic):
    output = []
    for i, desc in enumerate(descrip):
        if desc in list(heuristic.keys()):
            if heuristic[desc] == nii_type:
                 output.append(desc)
    return output

if __name__ == '__main__':
    #df = pd.read_csv("/data/henry7/james/antje_cohort/antje_transition_cohort.csv")
    #df = pd.read_csv("/data/henry7/james/all.csv")
    #df = pd.read_csv("/data/henry6/gina/msid.csv")
    df = pd.read_csv("/home/sf522915/ALL_EPIC_imaging_exams.csv")
    #msid_set = set(df['msid'])
    msid_set = set(df['not_done'])
    #msid_set_sorted = sorted(list(msid_set))
    #print("There are {} msid patient will be tested". format(len(msid_set_sorted)))

for _, row in df.iterrows():
    msid = row['msID']
    msid = str(msid)
    msid_ms = "ms" + str(msid)
    print(msid)

    out_filename = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/all/' + msid_ms + '.txt'
    mse_df = get_all_mse(msid)
    print(mse_df.mse)
    with open(out_filename, 'w') as f:
        mse_list = mse_df.mse
        for mse in mse_list:
            seriesDesc = get_modality(mse, "T1")
            print(seriesDesc["nii"], mse)
            if seriesDesc["nii"].any():
                f.write("{}\n".format(mse))
# Out:
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0056
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0060
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0064
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0069
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0070
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0071
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0073
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0077
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0078
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0086
# Series([], Name: mse, dtype: object)
# ms0109
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0135
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0165
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0170
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0171
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0172
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0173
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0174
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0175
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0176
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0179
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0181
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0184
# Series([], Name: mse, dtype: object)
# ms0185
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0195
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0198
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0227
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0230
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0241
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0242
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0243
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0245
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0247
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0248
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0249
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0270
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0282
# Series([], Name: mse, dtype: object)
# ms0286
# Series([], Name: mse, dtype: object)
# ms0286
# Series([], Name: mse, dtype: object)
# ms0286
# Series([], Name: mse, dtype: object)
# ms0286
# Series([], Name: mse, dtype: object)
# ms0286
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0376
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0378
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0386
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0387
# Series([], Name: mse, dtype: object)
# ms0388
# Series([], Name: mse, dtype: object)
# ms0388
# Series([], Name: mse, dtype: object)
# ms0388
# Series([], Name: mse, dtype: object)
# ms0388
# Series([], Name: mse, dtype: object)
# ms0388
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0405
# Series([], Name: mse, dtype: object)
# ms0407
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0408
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0421
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0424
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0451
# Series([], Name: mse, dtype: object)
# ms0459
# Series([], Name: mse, dtype: object)
# ms0459
# Series([], Name: mse, dtype: object)
# ms0459
# Series([], Name: mse, dtype: object)
# ms0459
# Series([], Name: mse, dtype: object)
# ms0459
# Series([], Name: mse, dtype: object)
# ms0460
# Series([], Name: mse, dtype: object)
# ms0460
# Series([], Name: mse, dtype: object)
# ms0460
# Series([], Name: mse, dtype: object)
# ms0460
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0463
# Series([], Name: mse, dtype: object)
# ms0487
# Series([], Name: mse, dtype: object)
# ms0487
# Series([], Name: mse, dtype: object)
# ms0487
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0493
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0494
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0498
# Series([], Name: mse, dtype: object)
# ms0499
# Series([], Name: mse, dtype: object)
# ms0499
# Series([], Name: mse, dtype: object)
# ms0499
# Series([], Name: mse, dtype: object)
# ms0499
# Series([], Name: mse, dtype: object)
# ms0499
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0500
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0501
# Series([], Name: mse, dtype: object)
# ms0502
# Series([], Name: mse, dtype: object)
# ms0502
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0509
# Series([], Name: mse, dtype: object)
# ms0510
# Series([], Name: mse, dtype: object)
# ms0510
# Series([], Name: mse, dtype: object)
# ms0510
# Series([], Name: mse, dtype: object)
# ms0510
# Series([], Name: mse, dtype: object)
# ms0510
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0511
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0512
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0513
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0514
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0515
# Series([], Name: mse, dtype: object)
# ms0519
# Series([], Name: mse, dtype: object)
# ms0519
# Series([], Name: mse, dtype: object)
# ms0519
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0520
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0521
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0522
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0523
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0527
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0528
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0529
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0530
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0531
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0532
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0534
# Series([], Name: mse, dtype: object)
# ms0535
# Series([], Name: mse, dtype: object)
# ms0535
# Series([], Name: mse, dtype: object)
# ms0535
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0537
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0538
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0539
# Series([], Name: mse, dtype: object)
# ms0540
# Series([], Name: mse, dtype: object)
# ms0540
# Series([], Name: mse, dtype: object)
# ms0540
# Series([], Name: mse, dtype: object)
# ms0540
# Series([], Name: mse, dtype: object)
# ms0540
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0541
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0542
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0544
# Series([], Name: mse, dtype: object)
# ms0545
# Series([], Name: mse, dtype: object)
# ms0545
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0546
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0547
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0548
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0549
# Series([], Name: mse, dtype: object)
# ms0555
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0556
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0557
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0558
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0559
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0560
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0561
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0562
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0563
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0564
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0567
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0568
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0569
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0570
# Series([], Name: mse, dtype: object)
# ms0571
# Series([], Name: mse, dtype: object)
# ms0571
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0572
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0573
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0575
# Series([], Name: mse, dtype: object)
# ms0576
# Series([], Name: mse, dtype: object)
# ms0576
# Series([], Name: mse, dtype: object)
# ms0576
# Series([], Name: mse, dtype: object)
# ms0576
# Series([], Name: mse, dtype: object)
# ms0576
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0577
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0578
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0579
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0580
# Series([], Name: mse, dtype: object)
# ms0581
# Series([], Name: mse, dtype: object)
# ms0581
# Series([], Name: mse, dtype: object)
# ms0581
# Series([], Name: mse, dtype: object)
# ms0581
# Series([], Name: mse, dtype: object)
# ms0582
# Series([], Name: mse, dtype: object)
# ms0582
# Series([], Name: mse, dtype: object)
# ms0583
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0584
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0585
# Series([], Name: mse, dtype: object)
# ms0586
# Series([], Name: mse, dtype: object)
# ms0586
# Series([], Name: mse, dtype: object)
# ms0586
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0587
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0588
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0591
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0592
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0593
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0594
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0595
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0596
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0597
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0598
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0599
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0618
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0620
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0621
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0622
# Series([], Name: mse, dtype: object)
# ms0623
# Series([], Name: mse, dtype: object)
# ms0623
# Series([], Name: mse, dtype: object)
# ms0623
# Series([], Name: mse, dtype: object)
# ms0623
# Series([], Name: mse, dtype: object)
# ms0623
# Series([], Name: mse, dtype: object)
# ms0623
# ...
# ms1684
# Series([], Name: mse, dtype: object)
# ms1684
# Series([], Name: mse, dtype: object)
# ms1684
# Series([], Name: mse, dtype: object)
# ms1691
# Series([], Name: mse, dtype: object)
# ms1691
# Series([], Name: mse, dtype: object)
# ms1692
# Series([], Name: mse, dtype: object)
# ms1692
# Series([], Name: mse, dtype: object)
# ms1692
# Series([], Name: mse, dtype: object)
# ms1695
# Series([], Name: mse, dtype: object)
# ms1695
# Series([], Name: mse, dtype: object)
# ms1695
# Series([], Name: mse, dtype: object)
# ms1695
# Series([], Name: mse, dtype: object)
# ms1696
# Series([], Name: mse, dtype: object)
# ms1696
# Series([], Name: mse, dtype: object)
# ms1696
# Series([], Name: mse, dtype: object)
# ms1697
# Series([], Name: mse, dtype: object)
# ms1697
# Series([], Name: mse, dtype: object)
# ms1697
# Series([], Name: mse, dtype: object)
# ms1709
# Series([], Name: mse, dtype: object)
# ms1709
# Series([], Name: mse, dtype: object)
# ms1709
# Series([], Name: mse, dtype: object)
# ms1709
# Series([], Name: mse, dtype: object)
# ms1711
# Series([], Name: mse, dtype: object)
# ms1711
# Series([], Name: mse, dtype: object)
# ms1711
# Series([], Name: mse, dtype: object)
# ms1711
# Series([], Name: mse, dtype: object)
# ms1715
# Series([], Name: mse, dtype: object)
# ms1715
# Series([], Name: mse, dtype: object)
# ms1715
# Series([], Name: mse, dtype: object)
# ms1716
# Series([], Name: mse, dtype: object)
# ms1716
# Series([], Name: mse, dtype: object)
# ms1716
# Series([], Name: mse, dtype: object)
# ms1716
# Series([], Name: mse, dtype: object)
# ms1723
# Series([], Name: mse, dtype: object)
# ms1723
# Series([], Name: mse, dtype: object)
# ms1723
# Series([], Name: mse, dtype: object)
# ms1723
# Series([], Name: mse, dtype: object)
# ms1723
# Series([], Name: mse, dtype: object)
# ms1726
# Series([], Name: mse, dtype: object)
# ms1726
# Series([], Name: mse, dtype: object)
# ms1726
# Series([], Name: mse, dtype: object)
# ms1726
# Series([], Name: mse, dtype: object)
# ms1729
# Series([], Name: mse, dtype: object)
# ms1729
# Series([], Name: mse, dtype: object)
# ms1729
# Series([], Name: mse, dtype: object)
# ms1729
# Series([], Name: mse, dtype: object)
# ms1738
# Series([], Name: mse, dtype: object)
# ms1738
# Series([], Name: mse, dtype: object)
# ms1738
# Series([], Name: mse, dtype: object)
# ms1738
# Series([], Name: mse, dtype: object)
# ms1751
# Series([], Name: mse, dtype: object)
# ms1758
# Series([], Name: mse, dtype: object)
# ms1758
# Series([], Name: mse, dtype: object)
# ms1758
# Series([], Name: mse, dtype: object)
# ms1766
# Series([], Name: mse, dtype: object)
# ms1776
# Series([], Name: mse, dtype: object)
# ms1776
# Series([], Name: mse, dtype: object)
# ms1776
# Series([], Name: mse, dtype: object)
# ms1779
# Series([], Name: mse, dtype: object)
# ms1779
# Series([], Name: mse, dtype: object)
# ms1783
# Series([], Name: mse, dtype: object)
# ms1784
# Series([], Name: mse, dtype: object)
# ms1784
# Series([], Name: mse, dtype: object)
# ms1784
# Series([], Name: mse, dtype: object)
# ms1784
# Series([], Name: mse, dtype: object)
# ms1785
# Series([], Name: mse, dtype: object)
# ms1785
# Series([], Name: mse, dtype: object)
# ms1785
# Series([], Name: mse, dtype: object)
# ms1785
# Series([], Name: mse, dtype: object)
# ms1792
# Series([], Name: mse, dtype: object)
# ms1792
# Series([], Name: mse, dtype: object)
# ms1792
# Series([], Name: mse, dtype: object)
# ms1796
# Series([], Name: mse, dtype: object)
# ms1796
# Series([], Name: mse, dtype: object)
# ms1796
# Series([], Name: mse, dtype: object)
# ms1796
# Series([], Name: mse, dtype: object)
# ms1796
# Series([], Name: mse, dtype: object)
# ms1797
# Series([], Name: mse, dtype: object)
# ms1797
# Series([], Name: mse, dtype: object)
# ms1797
# Series([], Name: mse, dtype: object)
# ms1797
# Series([], Name: mse, dtype: object)
# ms1798
# Series([], Name: mse, dtype: object)
# ms1798
# Series([], Name: mse, dtype: object)
# ms1798
# Series([], Name: mse, dtype: object)
# ms1801
# Series([], Name: mse, dtype: object)
# ms1801
# Series([], Name: mse, dtype: object)
# ms1801
# Series([], Name: mse, dtype: object)
# ms1802
# Series([], Name: mse, dtype: object)
# ms1803
# Series([], Name: mse, dtype: object)
# ms1803
# Series([], Name: mse, dtype: object)
# ms1803
# Series([], Name: mse, dtype: object)
# ms1804
# Series([], Name: mse, dtype: object)
# ms1804
# Series([], Name: mse, dtype: object)
# ms1804
# Series([], Name: mse, dtype: object)
# ms1804
# Series([], Name: mse, dtype: object)
# ms1807
# Series([], Name: mse, dtype: object)
# ms1807
# Series([], Name: mse, dtype: object)
# ms1807
# Series([], Name: mse, dtype: object)
# ms1813
# Series([], Name: mse, dtype: object)
# ms1813
# Series([], Name: mse, dtype: object)
# ms1813
# Series([], Name: mse, dtype: object)
# ms1814
# Series([], Name: mse, dtype: object)
# ms1814
# Series([], Name: mse, dtype: object)
# ms1814
# Series([], Name: mse, dtype: object)
# ms1814
# Series([], Name: mse, dtype: object)
# ms1821
# Series([], Name: mse, dtype: object)
# ms1821
# Series([], Name: mse, dtype: object)
# ms1822
# Series([], Name: mse, dtype: object)
# ms1822
# Series([], Name: mse, dtype: object)
# ms1830
# Series([], Name: mse, dtype: object)
# ms1830
# Series([], Name: mse, dtype: object)
# ms1832
# Series([], Name: mse, dtype: object)
# ms1834
# Series([], Name: mse, dtype: object)
# ms1834
# Series([], Name: mse, dtype: object)
# ms1836
# Series([], Name: mse, dtype: object)
# ms1836
# Series([], Name: mse, dtype: object)
# ms1836
# Series([], Name: mse, dtype: object)
# ms1840
# Series([], Name: mse, dtype: object)
# ms1842
# Series([], Name: mse, dtype: object)
# ms1846
# Series([], Name: mse, dtype: object)
# ms1846
# Series([], Name: mse, dtype: object)
# ms1851
# Series([], Name: mse, dtype: object)
# ms1851
# Series([], Name: mse, dtype: object)
# ms1856
# Series([], Name: mse, dtype: object)
# ms1856
# Series([], Name: mse, dtype: object)
# ms1856
# Series([], Name: mse, dtype: object)
# ms1857
# Series([], Name: mse, dtype: object)
# ms1858
# Series([], Name: mse, dtype: object)
# ms1858
# Series([], Name: mse, dtype: object)
# ms1858
# Series([], Name: mse, dtype: object)
# ms1859
# Series([], Name: mse, dtype: object)
# ms1859
# Series([], Name: mse, dtype: object)
# ms1859
# Series([], Name: mse, dtype: object)
# ms1863
# Series([], Name: mse, dtype: object)
# ms1863
# Series([], Name: mse, dtype: object)
# ms1863
# Series([], Name: mse, dtype: object)
# ms1865
# Series([], Name: mse, dtype: object)
# ms1865
# Series([], Name: mse, dtype: object)
# ms1865
# Series([], Name: mse, dtype: object)
# ms1882
# Series([], Name: mse, dtype: object)
# ms1886
# Series([], Name: mse, dtype: object)
# ms1886
# Series([], Name: mse, dtype: object)
# ms1894
# Series([], Name: mse, dtype: object)
# ms1894
# Series([], Name: mse, dtype: object)
# ms1894
# Series([], Name: mse, dtype: object)
# ms1907
# Series([], Name: mse, dtype: object)
# ms1907
# Series([], Name: mse, dtype: object)
# ms1907
# Series([], Name: mse, dtype: object)
# ms1907
# Series([], Name: mse, dtype: object)
# ms1908
# Series([], Name: mse, dtype: object)
# ms1908
# Series([], Name: mse, dtype: object)
# ms1908
# Series([], Name: mse, dtype: object)
# ms1914
# Series([], Name: mse, dtype: object)
# ms1914
# Series([], Name: mse, dtype: object)
# ms1914
# Series([], Name: mse, dtype: object)
# ms1918
# Series([], Name: mse, dtype: object)
# ms1918
# Series([], Name: mse, dtype: object)
# ms1920
# Series([], Name: mse, dtype: object)
# ms1920
# Series([], Name: mse, dtype: object)
# ms1920
# Series([], Name: mse, dtype: object)
# ms1921
# Series([], Name: mse, dtype: object)
# ms1926
# Series([], Name: mse, dtype: object)
# ms1926
# Series([], Name: mse, dtype: object)
# ms1926
# Series([], Name: mse, dtype: object)
# ms1927
# Series([], Name: mse, dtype: object)
# ms1927
# Series([], Name: mse, dtype: object)
# ms1927
# Series([], Name: mse, dtype: object)
# ms1927
# Series([], Name: mse, dtype: object)
# ms1939
# Series([], Name: mse, dtype: object)
# ms1959
# Series([], Name: mse, dtype: object)
# ms1959
# Series([], Name: mse, dtype: object)
# ms1967
# Series([], Name: mse, dtype: object)
# ms1967
# Series([], Name: mse, dtype: object)
# ms1967
# Series([], Name: mse, dtype: object)
# ms1979
# Series([], Name: mse, dtype: object)
# ms1979
# Series([], Name: mse, dtype: object)
# ms1979
# Series([], Name: mse, dtype: object)
# ms1990
# Series([], Name: mse, dtype: object)
# ms1990
# Series([], Name: mse, dtype: object)
# ms2013
# Series([], Name: mse, dtype: object)
# ms2015
# Series([], Name: mse, dtype: object)
# ms2015
# Series([], Name: mse, dtype: object)
# ms2016
# Series([], Name: mse, dtype: object)
# ms2016
# Series([], Name: mse, dtype: object)
# ms2089
# Series([], Name: mse, dtype: object)
# ms2094
# Series([], Name: mse, dtype: object)
# ms2094
# Series([], Name: mse, dtype: object)
# ms2097
# Series([], Name: mse, dtype: object)
# ms2097
# Series([], Name: mse, dtype: object)
# ms2097
# Series([], Name: mse, dtype: object)
# ms2110
# Series([], Name: mse, dtype: object)
# ms2117
# Series([], Name: mse, dtype: object)
# ms2117
# Series([], Name: mse, dtype: object)
# ms2120
# Series([], Name: mse, dtype: object)
# ms2120
# Series([], Name: mse, dtype: object)
# ms2171
# Series([], Name: mse, dtype: object)
# ms2173
# Series([], Name: mse, dtype: object)
# ms2173
# Series([], Name: mse, dtype: object)
# ms2174
# Series([], Name: mse, dtype: object)
# ms2174
# Series([], Name: mse, dtype: object)
# ms2175
# Series([], Name: mse, dtype: object)
# ms2175
# Series([], Name: mse, dtype: object)
# ms2176
# Series([], Name: mse, dtype: object)
# ms2176
# Series([], Name: mse, dtype: object)
# ms2176
# Series([], Name: mse, dtype: object)
# ms2184
# Series([], Name: mse, dtype: object)
# ms2184
# Series([], Name: mse, dtype: object)
# ms2184
# Series([], Name: mse, dtype: object)
# ms2185
# Series([], Name: mse, dtype: object)
# ms2195
# Series([], Name: mse, dtype: object)
# ms2195
# Series([], Name: mse, dtype: object)
# ms2199
# Series([], Name: mse, dtype: object)
# ms2199
# Series([], Name: mse, dtype: object)
# ms2199
# Series([], Name: mse, dtype: object)
# ms2200
# Series([], Name: mse, dtype: object)
# ms2200
# Series([], Name: mse, dtype: object)
# ms2200
# Series([], Name: mse, dtype: object)
# ms2202
# Series([], Name: mse, dtype: object)
# ms2202
# Series([], Name: mse, dtype: object)
# ms2202
# Series([], Name: mse, dtype: object)
# ms2203
# Series([], Name: mse, dtype: object)
# ms2203
# Series([], Name: mse, dtype: object)
# ms2206
# Series([], Name: mse, dtype: object)
# ms2206
# Series([], Name: mse, dtype: object)
# ms2214
# Series([], Name: mse, dtype: object)
# ms2217
# Series([], Name: mse, dtype: object)
# ms2217
# Series([], Name: mse, dtype: object)
# ms2221
# Series([], Name: mse, dtype: object)
# ms2221
# Series([], Name: mse, dtype: object)
# ms2221
# Series([], Name: mse, dtype: object)
# ms2223
# Series([], Name: mse, dtype: object)
# ms2223
# Series([], Name: mse, dtype: object)
# ms2223
# Series([], Name: mse, dtype: object)
# ms2225
# Series([], Name: mse, dtype: object)
# ms2225
# Series([], Name: mse, dtype: object)
# ms2225
# Series([], Name: mse, dtype: object)
# ms2230
# Series([], Name: mse, dtype: object)
# ms2231
# Series([], Name: mse, dtype: object)
# ms2231
# Series([], Name: mse, dtype: object)
# ms2231
# Series([], Name: mse, dtype: object)
# ms2232
# Series([], Name: mse, dtype: object)
# ms2232
# Series([], Name: mse, dtype: object)
# ms2234
# Series([], Name: mse, dtype: object)
# ms2234
# Series([], Name: mse, dtype: object)
# ms2235
# Series([], Name: mse, dtype: object)
# ms2236
# Series([], Name: mse, dtype: object)
# ms2236
# Series([], Name: mse, dtype: object)
# ms2243
# Series([], Name: mse, dtype: object)
# ms2243
# Series([], Name: mse, dtype: object)
# ms2243
# Series([], Name: mse, dtype: object)
# ms2245
# Series([], Name: mse, dtype: object)
# ms2245
# Series([], Name: mse, dtype: object)
# ms2245
# Series([], Name: mse, dtype: object)
# ms2250
# Series([], Name: mse, dtype: object)
# ms2250
# Series([], Name: mse, dtype: object)
# ms2250
# Series([], Name: mse, dtype: object)
# ms2265
# Series([], Name: mse, dtype: object)
# ms2265
# Series([], Name: mse, dtype: object)
# ms2295
# Series([], Name: mse, dtype: object)
# ms2299
# Series([], Name: mse, dtype: object)
# ms2299
# Series([], Name: mse, dtype: object)
# ms2308
# Series([], Name: mse, dtype: object)
# ms2312
# Series([], Name: mse, dtype: object)
# ms2312
# Series([], Name: mse, dtype: object)
# ms2313
# Series([], Name: mse, dtype: object)
# ms2313
# Series([], Name: mse, dtype: object)
# ms2314
# Series([], Name: mse, dtype: object)
# ms2314
# Series([], Name: mse, dtype: object)
# ms2314
# Series([], Name: mse, dtype: object)
# ms2319
# Series([], Name: mse, dtype: object)
# ms2319
# Series([], Name: mse, dtype: object)
# ms2319
# Series([], Name: mse, dtype: object)
# ms2898
# Series([], Name: mse, dtype: object)
# ms2898
# Series([], Name: mse, dtype: object)
# ms2898
# Series([], Name: mse, dtype: object)
# ms2928
# Series([], Name: mse, dtype: object)
# ms2928
# Series([], Name: mse, dtype: object)
# ms2932
# Series([], Name: mse, dtype: object)
# ms2932
# Series([], Name: mse, dtype: object)
# ms2934
# Series([], Name: mse, dtype: object)
# ms2934
# Series([], Name: mse, dtype: object)
# ms2934
# Series([], Name: mse, dtype: object)
# ms2934
# Series([], Name: mse, dtype: object)
# ms2952
# Series([], Name: mse, dtype: object)
# ms2952
# Series([], Name: mse, dtype: object)
# ms2952
# Series([], Name: mse, dtype: object)
# ms2953
# Series([], Name: mse, dtype: object)
# ms2953
# Series([], Name: mse, dtype: object)
# ms2953
# Series([], Name: mse, dtype: object)
# ms2955
# Series([], Name: mse, dtype: object)
# ms2955
# Series([], Name: mse, dtype: object)
# ms2960
# Series([], Name: mse, dtype: object)
# ms2960
# Series([], Name: mse, dtype: object)
# ms2982
# Series([], Name: mse, dtype: object)
# ms2982
# Series([], Name: mse, dtype: object)
# ms2985
# Series([], Name: mse, dtype: object)
# ms2985
# Series([], Name: mse, dtype: object)
# ms2990
# Series([], Name: mse, dtype: object)
# ms2990
# Series([], Name: mse, dtype: object)
# ms3036
# Series([], Name: mse, dtype: object)
# ms3036
# Series([], Name: mse, dtype: object)
# ms3098
# Series([], Name: mse, dtype: object)
# ms3133
# Series([], Name: mse, dtype: object)
# ms3133
# Series([], Name: mse, dtype: object)
# ms3135
# Series([], Name: mse, dtype: object)
# ms3136
# Series([], Name: mse, dtype: object)
# ms3136
# Series([], Name: mse, dtype: object)
# ms3138
# Series([], Name: mse, dtype: object)
# ms3138
# Series([], Name: mse, dtype: object)
# ms3186
# Series([], Name: mse, dtype: object)
# ms3186
# Series([], Name: mse, dtype: object)
# ms3187
# Series([], Name: mse, dtype: object)
# ms3187
# Series([], Name: mse, dtype: object)
# ms3187
# Series([], Name: mse, dtype: object)
# ms3187
# Series([], Name: mse, dtype: object)
# ms3188
# Series([], Name: mse, dtype: object)
# ms3189
# Series([], Name: mse, dtype: object)
# ms3190
# Series([], Name: mse, dtype: object)
# ms3190
# Series([], Name: mse, dtype: object)
# ms3193
# Series([], Name: mse, dtype: object)
# ms3193
# Series([], Name: mse, dtype: object)
# ms3209
# Series([], Name: mse, dtype: object)
# ms3278
# Series([], Name: mse, dtype: object)
# ms3292
# Series([], Name: mse, dtype: object)
# ms3296
# Series([], Name: mse, dtype: object)
# ms3299
# Series([], Name: mse, dtype: object)
# ms3314
# Series([], Name: mse, dtype: object)
# ms3316
# Series([], Name: mse, dtype: object)
# ms3316
# Series([], Name: mse, dtype: object)
# ms3350
# Series([], Name: mse, dtype: object)
# ms3351
# Series([], Name: mse, dtype: object)
# ms3351
# Series([], Name: mse, dtype: object)
# ms3373
# Series([], Name: mse, dtype: object)
# ms3376
# Series([], Name: mse, dtype: object)
# ms3378
# Series([], Name: mse, dtype: object)
# ms3379
# Series([], Name: mse, dtype: object)
# ms3397
# Series([], Name: mse, dtype: object)
# ms3404
# Series([], Name: mse, dtype: object)
# ms3407
# Series([], Name: mse, dtype: object)
# ms3415
# Series([], Name: mse, dtype: object)
# ms3416
# Series([], Name: mse, dtype: object)
# ms3416
# Series([], Name: mse, dtype: object)
# ms3416
# Series([], Name: mse, dtype: object)
# ms3417
# Series([], Name: mse, dtype: object)
# ms3417
# Series([], Name: mse, dtype: object)
# ms3463
# Series([], Name: mse, dtype: object)
# ms3478
# Series([], Name: mse, dtype: object)
# ms3492
# Series([], Name: mse, dtype: object)
# ms3518
# Series([], Name: mse, dtype: object)
# ms3520
# Series([], Name: mse, dtype: object)
# ms3586
# Series([], Name: mse, dtype: object)
# ms3591
# Series([], Name: mse, dtype: object)
# ms3608
# Series([], Name: mse, dtype: object)
# ms3610
# Series([], Name: mse, dtype: object)
# ms3616
# Series([], Name: mse, dtype: object)
# ms3617
# Series([], Name: mse, dtype: object)
# ms3625
# Series([], Name: mse, dtype: object)
# ms3636
# Series([], Name: mse, dtype: object)
# ms3672
# Series([], Name: mse, dtype: object)
# ms3697
# Series([], Name: mse, dtype: object)
# ms3710
# Series([], Name: mse, dtype: object)
# ms3727
# Series([], Name: mse, dtype: object)
# ms3731
# Series([], Name: mse, dtype: object)
