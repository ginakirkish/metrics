# %%
from glob import glob
import pandas as pd
import numpy as np
import csv
import os
# %pylab inline
import matplotlib.pyplot as plt
from subprocess import check_output
from subprocess import Popen, PIPE
import shutil
import itertools
from itertools import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
writer = open("/data/pelletier1/genentech/csv_xlsx/all_mse.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mseID"])
spreadsheet.writeheader()

# %%
with open('/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/EPIC_ms/ms1048.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line for line in stripped if line)
    print(grouped)
    with open('/data/pelletier1/genentech/csv_xlsx/all_mse.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('msid', 'mse'))
        writer.writerows(lines)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-670bc217414d> in <module>()
#       2     stripped = (line.strip() for line in in_file)
#       3     lines = (line for line in stripped if line)
# ----> 4     grouped = itertools.izip(*[lines] * 3)
#       5     print(grouped)
#       6     with open('/data/pelletier1/genentech/csv_xlsx/all_mse.csv', 'w') as out_file:
#
# AttributeError: module 'itertools' has no attribute 'izip'

# %%
with open('/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/EPIC_ms/ms1048.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line for line in stripped if line)
    #grouped = itertools.izip(*[lines] * 3)
    with open('/data/pelletier1/genentech/csv_xlsx/all_mse.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('msid', 'mse'))
        writer.writerows(lines)

# %%
for text_file in os.listdir("/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/EPIC_ms"):
    print(text_file)
    with open(text_file, 'a') as my_file:
        print(f)
            #f.write(mseid +"\n")
# Out:
# ms56.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms64.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms69.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms70.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms71.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms73.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms78.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms86.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms135.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms165.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms170.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms171.txt
# <_io.TextIOWrapper name='ms1939.txt' mode='r' encoding='UTF-8'>
# ms172.txt
# ...

# %%
writer = open("/data/pelletier1/genentech/csv_xlsx/all_mse.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mse_tp1", "mse_tp2",\
                                                "mse_tp3", "mse_tp4", "mse_tp5", "mse_tp6",\
                                                "mse_tp7", "mse_tp8", "mse_tp9", "mse_tp10", "mse_tp11", "mse_tp12", "mse_tp13",
                                                "mse_tp14", "mse_tp15", "mse_tp16", "mse_tp17", "mse_tp18", "mse_tp19", "mse_tp20"])

veo_base = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/EPIC_ms/'
for text in os.listdir(veo_base):
    msid = text.replace(".txt","")
    with open(veo_base + text) as f:
        content = f.readlines()
        mse = [x.strip() for x in content] 
        #print(len(content), mse, msid)
        tp_total = len(content)
        print(tp_total)
        towrite = {}
        if tp_total == 0:
            print(tp_total, mse, msid)
            continue
        if tp_total == 1: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            spreadsheet.writerow(towrite)
        if tp_total == 2: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            #towrite["mse_tp1"] = mse[2]
            spreadsheet.writerow(towrite)
        if tp_total == 3: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            spreadsheet.writerow(towrite)
        if tp_total == 4: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            spreadsheet.writerow(towrite)
        if tp_total == 5: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            spreadsheet.writerow(towrite)
        if tp_total == 6: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            spreadsheet.writerow(towrite)
        if tp_total == 7: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            spreadsheet.writerow(towrite)
        if tp_total == 8: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            spreadsheet.writerow(towrite)
        if tp_total == 9: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            spreadsheet.writerow(towrite)
        if tp_total == 10: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            spreadsheet.writerow(towrite)
        if tp_total == 11: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            spreadsheet.writerow(towrite)
        if tp_total == 12: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            spreadsheet.writerow(towrite)
        if tp_total == 13: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            spreadsheet.writerow(towrite)
        if tp_total == 14: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            spreadsheet.writerow(towrite)
        if tp_total == 15: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            spreadsheet.writerow(towrite)
        if tp_total == 16: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            
            spreadsheet.writerow(towrite)
        if tp_total == 17: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            towrite["mse_tp17"] =mse[16]
            spreadsheet.writerow(towrite)
        if tp_total == 18: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            towrite["mse_tp17"] =mse[16]
            towrite["mse_tp17"] =mse[17]
            spreadsheet.writerow(towrite)
            
        else:
            continue
        
writer.close()
# Out:
# 9
# 9 ['mse1328', 'mse1329', 'mse1330', 'mse1331', 'mse1332', 'mse1333', 'mse5768', 'mse4114', 'mse6952'] ms56
# 8
# 8 ['mse1337', 'mse1338', 'mse1339', 'mse1340', 'mse1341', 'mse1342', 'mse4285', 'mse6529'] ms64
# 7
# 7 ['mse1343', 'mse1344', 'mse1345', 'mse1346', 'mse1347', 'mse1348', 'mse4287'] ms69
# 18
# 18 ['mse8582', 'mse1349', 'mse1350', 'mse1351', 'mse8581', 'mse8580', 'mse8579', 'mse8578', 'mse8577', 'mse8576', 'mse8575', 'mse1352', 'mse1353', 'mse1354', 'mse4289', 'mse8572', 'mse2910', 'mse5616'] ms70
# 9
# 9 ['mse1355', 'mse1356', 'mse1357', 'mse1358', 'mse1359', 'mse1360', 'mse4291', 'mse3041', 'mse5276'] ms71
# 8
# 8 ['mse1361', 'mse1362', 'mse1363', 'mse1364', 'mse1365', 'mse1366', 'mse4292', 'mse4293'] ms73
# 10
# 10 ['mse1373', 'mse1374', 'mse1375', 'mse1376', 'mse1377', 'mse1378', 'mse5415', 'mse2924', 'mse5379', 'mse8775'] ms78
# 10
# 10 ['mse1379', 'mse3574', 'mse1380', 'mse1381', 'mse1382', 'mse1383', 'mse4295', 'mse4707', 'mse5622', 'mse8450'] ms86
# 10
# ...

# %%
writer = open("/data/pelletier1/genentech/csv_xlsx/all_mse.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mse_tp1", "mse_tp2",\
                                                "mse_tp3", "mse_tp4", "mse_tp5", "mse_tp6",\
                                                "mse_tp7", "mse_tp8", "mse_tp9", "mse_tp10", "mse_tp11"])
spreadsheet.writeheader()
veo_base = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/EPIC_ms/'
counter = 0 
for text in os.listdir(veo_base):
    msid = text.replace(".txt","")
    with open(veo_base + text) as f:

        content = f.readlines()
        print(len(content))

            
        mse = [x.strip() for x in content] 
        print(mse[0], msid)
        towrite = {}
        towrite["msID"] = msid
        
        towrite["mse_tp1"] = mse[0]
        
        towrite["mse_tp2"] = mse[1]
        towrite["mse_tp3"] = mse[2]
        towrite["mse_tp4"] = mse[3]
        towrite["mse_tp5"] = mse[4]
        towrite["mse_tp6"] = mse[5]
        towrite["mse_tp7"] = mse[6]
        if len(content > 7):
            towrite["mse_tp8"] = mse[7]
        
        spreadsheet.writerow(towrite)
writer.close()
# Out:
# 9
# mse1328 ms56
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-ce8db2f61f26> in <module>()
#      25         towrite["mse_tp6"] = mse[5]
#      26         towrite["mse_tp7"] = mse[6]
# ---> 27         if len(content > 7):
#      28             towrite["mse_tp8"] = mse[7]
#      29
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
df = pd.read_csv("/data/pelletier1/genentech/csv_xlsx/all_mse.csv")
for _, row in df.iterrows():
    tp1 = row['msid']
    #print(tp1)
    if os.path.exists("/data/henry7/PBR/subjects/"+ tp1 + "/t1Ants_reg_long/"):
        #for nii in os.listdir("/data/henry7/PBR/subjects/"+ tp1 + "/t1ants_reg_long/"):
            
        print(tp1, "YES")
    else:
        print(tp1)
# Out:
# ms1048
# ms1049 YES
# ms1050
# ms1051
# ms1052
# ms1053
# ms1054
# ms1058
# ms1059
# ms1060 YES
# ms1061 YES
# ms1062
# ms1064
# ms1065 YES
# ms1069
# ms1071
# ms1073
# ms1077
# ms1078
# ms1079
# ms1080 YES
# ms1081
# ms1082
# ms1084
# ms1092
# ms1093
# ms1094
# ms1095 YES
# ms1096
# ms1099
# ms1100
# ms1104
# ms1105
# ms1106
# ms1107
# ms1108 YES
# ms1110
# ms1111
# ms1112
# ms1113
# ms1114
# ms1121
# ms1122
# ms1123
# ms1124
# ms1126 YES
# ms1127
# ms1128
# ms1131
# ms1132
# ms1136 YES
# ms1137
# ms1138
# ms1147 YES
# ms1148 YES
# ms1149 YES
# ms1157
# ms1159 YES
# ms1161
# ms1163
# ms1164
# ms1166
# ms1168
# ms1179
# ms1181
# ms1182
# ms1184
# ms1187
# ms1192
# ms1194
# ms1195
# ms1196
# ms1197
# ms1199 YES
# ms1200
# ms1201
# ms1205
# ms1206
# ms1207
# ms1209
# ms1210
# ms1212 YES
# ms1214
# ms1217
# ms1224
# ms1225
# ms1227 YES
# ms1229
# ms1230 YES
# ms1231
# ms1232
# ms1233
# ms1234 YES
# ms1236
# ms1237
# ms1238 YES
# ms1239
# ms1240
# ms1242
# ms1243
# ms1245 YES
# ms1246
# ...

# %%
writer = open("/data/pelletier1/genentech/genentech_cb_and_skyra_withmse.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mseID", "ExamDate", "ExamDate2"])
spreadsheet.writeheader()
df = pd.read_excel("/data/pelletier1/genentech/genentech_cb_and_skyra_data_alyssa.xls")
for _, row in df.iterrows():
    msid = row['msid']
    msid = msid.replace("ms", "")
    date1 = row['date']
    cmd = ["ms_get_patient_imaging_exams", "--patient_id", msid, "--dcm_dates"]
    proc = Popen(cmd, stdout=PIPE)
    lines = [l.decode("utf-8").split() for l in proc.stdout.readlines()[5:]]
    tmp = pd.DataFrame(lines, columns=["mse", "date"])
    tmp["msid"] = msid
    mse = tmp["mse"]
    date2 = tmp["date"]
    for _, row in tmp.iterrows():
        mse = row["mse"]
        date2 = row["date"]
        if str(date1) == (date2):
            print msid, mse, date2, date1
            towrite = {}
            towrite["msID"] = "ms"+ msid.zfill(4)
            towrite["mseID"] = "mse"+ mse.zfill(4)
            towrite["ExamDate"] = str(date1)
            spreadsheet.writerow(towrite)
        else:
            continue
    #break
writer.close()

# %%
writer = open("/home/sf522915/antje_cohort.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mse_tp1", "mse_tp2",\
                                                "mse_tp3", "mse_tp4", "mse_tp5", "mse_tp6",\
                                                "mse_tp7", "mse_tp8", "mse_tp9", "mse_tp10", "mse_tp11", "mse_tp12", "mse_tp13",
                                                "mse_tp14", "mse_tp15", "mse_tp16", "mse_tp17", "mse_tp18", "mse_tp19", "mse_tp20"])

veo_base = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/antje_cohort/'
for text in os.listdir(veo_base):
    msid = text.replace(".txt","")
    with open(veo_base + text) as f:
        content = f.readlines()
        mse = [x.strip() for x in content] 
        #print(len(content), mse, msid)
        tp_total = len(content)
        print(tp_total)
        towrite = {}
        if tp_total == 0:
            print(tp_total, mse, msid)
            continue
        if tp_total == 1: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            spreadsheet.writerow(towrite)
        if tp_total == 2: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            #towrite["mse_tp1"] = mse[2]
            spreadsheet.writerow(towrite)
        if tp_total == 3: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            spreadsheet.writerow(towrite)
        if tp_total == 4: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            spreadsheet.writerow(towrite)
        if tp_total == 5: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            spreadsheet.writerow(towrite)
        if tp_total == 6: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            spreadsheet.writerow(towrite)
        if tp_total == 7: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            spreadsheet.writerow(towrite)
        if tp_total == 8: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            spreadsheet.writerow(towrite)
        if tp_total == 9: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            spreadsheet.writerow(towrite)
        if tp_total == 10: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            spreadsheet.writerow(towrite)
        if tp_total == 11: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            spreadsheet.writerow(towrite)
        if tp_total == 12: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            spreadsheet.writerow(towrite)
        if tp_total == 13: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            spreadsheet.writerow(towrite)
        if tp_total == 14: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            spreadsheet.writerow(towrite)
        if tp_total == 15: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            spreadsheet.writerow(towrite)
        if tp_total == 16: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            
            spreadsheet.writerow(towrite)
        if tp_total == 17: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            towrite["mse_tp17"] =mse[16]
            spreadsheet.writerow(towrite)
        if tp_total == 18: 
            print(tp_total, mse, msid)
            towrite["msID"] = msid
            towrite["mse_tp1"] = mse[0]
            towrite["mse_tp2"] = mse[1]
            towrite["mse_tp3"] = mse[2]
            towrite["mse_tp4"] = mse[3]
            towrite["mse_tp5"] = mse[4]
            towrite["mse_tp6"] = mse[5]
            towrite["mse_tp7"] = mse[6]
            towrite["mse_tp8"] = mse[7]
            towrite["mse_tp9"] = mse[8]
            towrite["mse_tp10"] = mse[9]
            towrite["mse_tp11"] = mse[10]
            towrite["mse_tp12"] = mse[11]
            towrite["mse_tp13"] =mse[12]
            towrite["mse_tp14"] =mse[13]
            towrite["mse_tp15"] =mse[14]
            towrite["mse_tp16"] =mse[15]
            towrite["mse_tp17"] =mse[16]
            towrite["mse_tp17"] =mse[17]
            spreadsheet.writerow(towrite)
            
        else:
            continue
        
writer.close()
# Out:
# 8
# 8 ['mse1827', 'mse1828', 'mse1829', 'mse1830', 'mse1831', 'mse1832', 'mse5769', 'mse5412'] ms1049
# 7
# 7 ['mse1872', 'mse3644', 'mse1873', 'mse1874', 'mse1875', 'mse4534', 'mse6638'] ms1060
# 6
# 6 ['mse1876', 'mse1877', 'mse1878', 'mse1879', 'mse1880', 'mse5779'] ms1061
# 8
# 8 ['mse1894', 'mse3656', 'mse1895', 'mse1896', 'mse1897', 'mse1898', 'mse4537', 'mse6463'] ms1065
# 7
# 7 ['mse1936', 'mse3659', 'mse1938', 'mse3660', 'mse1939', 'mse5763', 'mse6210'] ms1080
# 8
# 8 ['mse1980', 'mse1981', 'mse1982', 'mse1983', 'mse1984', 'mse5842', 'mse2909', 'mse5360'] ms1095
# 7
# 7 ['mse2031', 'mse3675', 'mse2032', 'mse2033', 'mse2034', 'mse4560', 'mse5427'] ms1108
# 8
# 8 ['mse2087', 'mse3680', 'mse2088', 'mse2089', 'mse2090', 'mse2091', 'mse4576', 'mse6711'] ms1126
# 10
# 10 ['mse2119', 'mse2120', 'mse2121', 'mse2122', 'mse2123', 'mse2124', 'mse4583', 'mse4751', 'mse4387', 'mse7950'] ms1136
# 9
# ...

# %%
writer = open("/home/sf522915/antje_cohort.csv", "w")
spreadsheet = csv.DictWriter(writer, fieldnames=["msID", "mse"])

veo_base = '/data/henry6/mindcontrol_ucsf_env/watchlists/long/VEO/antje_cohort/'
for text in os.listdir(veo_base):
    msid = text.replace(".txt","")
    with open(veo_base + text) as f:
        content = f.readlines()
        mse = [x.strip() for x in content] 
        #print(len(content), mse, msid)
        tp_total = len(content)
        print(tp_total)
        towrite = {}
        towrite["msID"] = msid
        for m in mse:
            print(m)
            towrite["mse"] = m
            spreadsheet.writerow(towrite)
        
writer.close()
# Out:
# 8
# mse1827
# mse1828
# mse1829
# mse1830
# mse1831
# mse1832
# mse5769
# mse5412
# 7
# mse1872
# mse3644
# mse1873
# mse1874
# mse1875
# mse4534
# mse6638
# 6
# mse1876
# mse1877
# mse1878
# mse1879
# mse1880
# mse5779
# 8
# mse1894
# mse3656
# mse1895
# mse1896
# mse1897
# mse1898
# mse4537
# mse6463
# 7
# mse1936
# mse3659
# mse1938
# mse3660
# mse1939
# mse5763
# mse6210
# 8
# mse1980
# mse1981
# mse1982
# mse1983
# mse1984
# mse5842
# mse2909
# mse5360
# 7
# mse2031
# mse3675
# mse2032
# mse2033
# mse2034
# mse4560
# mse5427
# 8
# mse2087
# mse3680
# mse2088
# mse2089
# mse2090
# mse2091
# mse4576
# mse6711
# 10
# mse2119
# mse2120
# mse2121
# mse2122
# mse2123
# mse2124
# mse4583
# mse4751
# mse4387
# mse7950
# 9
# mse2132
# mse2133
# mse2134
# mse2135
# mse2136
# mse2137
# mse4586
# mse4054
# mse6842
# 9
# mse2138
# mse2139
# mse2140
# mse3687
# mse2141
# mse2142
# mse2143
# mse4588
# mse6657
# 8
# mse2144
# mse2145
# mse2146
# mse2147
# mse2148
# mse2149
# mse5788
# mse6789
# ...
